# %% [markdown]
# ## Process data

# %%
import bz2
import csv
import gzip
import json
import os
import random

import fasttext

# %%
file_parts_dir = './file_parts/'
base_fasttext_fn = './fasttext/wd_2020_11_02.txt'
groundtruth_data = 'labeled_enwiki_with_topics_metadata.json.bz2'  # same labeled data as used by outlinks

train_prop = 0.9
val_prop = 0.02
test_prop = 0.08
assert train_prop + val_prop + test_prop == 1
train_fn = base_fasttext_fn.replace('.txt', '_train.txt')
train_metadata_fn = base_fasttext_fn.replace('.txt', '_train_metadata.txt')
val_fn = base_fasttext_fn.replace('.txt', '_val.txt')
val_metadata_fn = base_fasttext_fn.replace('.txt', '_val_metadata.txt')
test_fn = base_fasttext_fn.replace('.txt', '_test.txt')
test_metadata_fn = base_fasttext_fn.replace('.txt', '_test_metadata.txt')
nogroundtruth_fn = base_fasttext_fn.replace('.txt', '_nogt.txt')
nogroundtruth_metadata_fn = base_fasttext_fn.replace('.txt', '_nogt_metadata.txt')

# %%
# !mkdir './fasttext'
# !hdfs dfs -copyToLocal 'wikidata-statements-enwiki/part*' '{file_parts_dir}'

# %%
# quickly combine many CSV parts into a single CSV (with metadata removed for fastText)
fns = [fn for fn in os.listdir(file_parts_dir) if fn.endswith('.csv.gz')]
embeddings_output = 'wikidata_embeddings_enwiki.tsv.bz2'
print_every = 1
input_header = ['item_id', 'statements']
empty = 0
processed = 0
with bz2.open(embeddings_output, 'wt') as fout:
    for i, fn in enumerate(fns, start=1):
        with gzip.open(os.path.join(file_parts_dir, fn), 'rt') as fin:
            # the quote symbol " is somehow a valid username character...
            header = next(fin).strip().split('\t')
            assert header == input_header
            for line_no, line_str in enumerate(fin, start=1):
                line = line_str.strip().split('\t')
                assert len(line) == 2
                qid = line[0]
                prop_vals = line[1]
                if len(prop_vals) == 0:
                    empty += 1
                emb = ' '.join(['{0:.3f}'.format(d) for d in ft_model.get_sentence_vector(prop_vals)])
                fout.write('{0}\t{1}\n'.format(qid, emb))
                processed += 1
        if i % print_every == 0:
            print("{0} / {1} files processed. {2} of {3} empty.".format(i, len(fns), empty, processed))
            print_every = print_every * 2
# Out:
# 1 / 200 files processed. 0 of 30483 empty.
# 2 / 200 files processed. 0 of 60741 empty.
# 4 / 200 files processed. 0 of 121591 empty.
# 8 / 200 files processed. 0 of 243789 empty.
# 16 / 200 files processed. 0 of 486460 empty.
# 32 / 200 files processed. 0 of 971618 empty.
# 64 / 200 files processed. 0 of 1943770 empty.
# 128 / 200 files processed. 0 of 3888819 empty.

# %% [markdown]
# ## Prepare Training Data

# %%
def fasttextify(topic):
    """Translate articletopic labels into fastText format (prefixed with __label__ and no spaces)."""
    return '__label__{0}'.format(topic.replace(' ', '_'))

# %%
# load in groundtruth
qid_topics = {}
with bz2.open(groundtruth_data, 'rt') as fin:
    for line in fin:
        line = json.loads(line)
        qid = line.get('qid')
        topics = line.get('topics')
        if qid and topics:
            qid_topics[qid] = topics
print("{0} QIDs with topics.".format(len(qid_topics)))
# Out:
# 5662388 QIDs with topics.

# %%
# !zless ./file_parts/part-00000-53a7157b-9779-4919-843d-8ac5abaa9cb6-c000.csv.gz | head
# Out:
# item_id	statements
# Q1000211	P18 P214 P1313 Q65191356 P6671 P17 Q142 P31 Q484170 P1566 P1616 P7938 Q574168 P373 P1082 P1082 P1082 P1082 P4212 P856 P646 P131 Q3093 P131 Q701410 P6766 P2046 P8422 P374 P47 Q325587 P47 Q988888 P47 Q872458 P47 Q378973 P47 Q868812 P47 Q867323 P625 P1448 P166 Q2727598 P281
# Q1000919	P244 P571 P18 P214 P31 Q43229 P373 P856 P7859 P625 P112 Q741873 P1315 P213 P3500 P3057
# Q100124689	P361 Q99766252 P361 Q6591877 P17 Q408 P31 Q1057954 P991 Q5128951 P1697 P5044 P1867 P1868 P541 Q19202748 P585 P155 Q100098032
# Q100158694	P31 Q5 P21 Q6581072 P569 P106 Q43845 P106 Q483501
# Q100159873	P31 Q5 P569 P106 Q12299841 P735 Q18336566 P21 Q6581097
# Q100166237	P31 Q11173 P31 Q2612896 P662 P117
# Q100168290	P31 Q5 P569 P106 Q937857 P21 Q6581097 P19 Q3808
# Q1001788	P244 P571 P1454 Q134161 P214 P31 Q4830453 P31 Q6881511 P856 P7859 P3347 P452 Q44497 P646 P414 Q13677 P154 P159 Q2868
# Q1001929	P571 P18 P454 P3518 P649 P214 P1435 Q19558910 P17 Q30 P31 Q12323 P1566 P373 P4661 Q35043122 P646 P5904 P138 Q202285 P131 Q156385 P30 Q49 P625 P625 P8226 P5383 P4614 Q47007487 P706 Q919146

# %%
train_written = 0
val_written = 0
test_written = 0
nogt_written = 0
i = 0
fns = [fn for fn in os.listdir(file_parts_dir) if fn.endswith('.csv.gz')]
qids_to_split = {}
input_header = ['item_id', 'statements']
with open(train_fn, 'w') as train_fout:
    with open(train_metadata_fn, 'w') as train_metadata_fout:
        with open(val_fn, 'w') as val_fout:
            with open(val_metadata_fn, 'w') as val_metadata_fout:
                with open(test_fn, 'w') as test_fout:
                    with open(test_metadata_fn, 'w') as test_metadata_fout:
                        with open(nogroundtruth_fn, 'w') as nogt_fout:
                            with open(nogroundtruth_metadata_fn, 'w') as nogt_metadata_fout:
                                for fidx, fn in enumerate(fns, start=1):
                                    with gzip.open(os.path.join(file_parts_dir, fn), 'rt') as fin:
                                        header = next(fin).strip().split('\t')
                                        assert header == input_header
                                        for i, line_str in enumerate(fin, start=1):
                                            line = line_str.strip().split('\t')
                                            assert len(line) == len(input_header)
                                            qid = line[0]
                                            prop_vals = line[1]
                                            if not prop_vals or not qid:
                                                continue
                                            topics = qid_topics.get(qid)
                                            if topics:
                                                if qid in qids_to_split:
                                                    r = qids_to_split[qid]
                                                else:
                                                    r = random.random()
                                                    qids_to_split[qid] = r
                                                if r <= train_prop:
                                                    data_fout = train_fout
                                                    metadata_fout = train_metadata_fout
                                                    train_written += 1
                                                elif r <= train_prop + val_prop:
                                                    data_fout = val_fout
                                                    metadata_fout = val_metadata_fout
                                                    val_written += 1
                                                else:
                                                    data_fout = test_fout
                                                    metadata_fout = test_metadata_fout
                                                    test_written += 1
                                            else:
                                                topics = []
                                                data_fout = nogt_fout
                                                metadata_fout = nogt_metadata_fout
                                                nogt_written += 1
                                            data_fout.write('{0} {1}\n'.format(' '.join([fasttextify(t) for t in topics]), prop_vals))
                                            metadata_fout.write('{0}\n'.format(qid))
                                    print("{0} of {1} processed: {2} train. {3} val. {4} test. {5} no groundtruth.".format(fidx, len(fns),
                                                                                                                           train_written,
                                                                                                                           val_written,
                                                                                                                           test_written,
                                                                                                                           nogt_written))
# Out:
# 1 of 200 processed: 24549 train. 573 val. 2229 test. 3132 no groundtruth.
# 2 of 200 processed: 49172 train. 1159 val. 4385 test. 6025 no groundtruth.
# 3 of 200 processed: 73810 train. 1690 val. 6513 test. 9023 no groundtruth.
# 4 of 200 processed: 98573 train. 2240 val. 8728 test. 12050 no groundtruth.
# 5 of 200 processed: 123223 train. 2740 val. 10905 test. 15068 no groundtruth.
# 6 of 200 processed: 147925 train. 3216 val. 13201 test. 18093 no groundtruth.
# 7 of 200 processed: 172832 train. 3769 val. 15373 test. 21183 no groundtruth.
# 8 of 200 processed: 197707 train. 4357 val. 17595 test. 24130 no groundtruth.
# 9 of 200 processed: 222071 train. 4899 val. 19793 test. 27153 no groundtruth.
# 10 of 200 processed: 246552 train. 5456 val. 21956 test. 30178 no groundtruth.
# 11 of 200 processed: 271102 train. 6025 val. 24164 test. 33246 no groundtruth.
# 12 of 200 processed: 295652 train. 6541 val. 26331 test. 36271 no groundtruth.
# 13 of 200 processed: 320198 train. 7110 val. 28525 test. 39310 no groundtruth.
# 14 of 200 processed: 344720 train. 7648 val. 30716 test. 42444 no groundtruth.
# 15 of 200 processed: 369592 train. 8212 val. 32950 test. 45539 no groundtruth.
# 16 of 200 processed: 394061 train. 8784 val. 35113 test. 48502 no groundtruth.
# 17 of 200 processed: 418754 train. 9316 val. 37348 test. 51565 no groundtruth.
# 18 of 200 processed: 443664 train. 9871 val. 39493 test. 54677 no groundtruth.
# 19 of 200 processed: 467964 train. 10401 val. 41707 test. 57629 no groundtruth.
# 20 of 200 processed: 492523 train. 10935 val. 43928 test. 60641 no groundtruth.
# 21 of 200 processed: 517169 train. 11460 val. 46156 test. 63619 no groundtruth.
# 22 of 200 processed: 541854 train. 12012 val. 48417 test. 66602 no groundtruth.
# 23 of 200 processed: 566218 train. 12565 val. 50626 test. 69664 no groundtruth.
# 24 of 200 processed: 590647 train. 13094 val. 52800 test. 72735 no groundtruth.
# 25 of 200 processed: 615504 train. 13626 val. 54998 test. 75728 no groundtruth.
# 26 of 200 processed: 640030 train. 14164 val. 57194 test. 78800 no groundtruth.
# 27 of 200 processed: 664650 train. 14709 val. 59364 test. 81762 no groundtruth.
# 28 of 200 processed: 689076 train. 15257 val. 61506 test. 84778 no groundtruth.
# 29 of 200 processed: 713561 train. 15825 val. 63682 test. 87768 no groundtruth.
# 30 of 200 processed: 738043 train. 16384 val. 65858 test. 90717 no groundtruth.
# 31 of 200 processed: 762333 train. 16921 val. 68008 test. 93767 no groundtruth.
# 32 of 200 processed: 787169 train. 17456 val. 70200 test. 96793 no groundtruth.
# 33 of 200 processed: 811732 train. 18027 val. 72364 test. 99885 no groundtruth.
# 34 of 200 processed: 836174 train. 18537 val. 74419 test. 102961 no groundtruth.
# 35 of 200 processed: 860683 train. 19104 val. 76520 test. 106033 no groundtruth.
# 36 of 200 processed: 885082 train. 19616 val. 78735 test. 109072 no groundtruth.
# 37 of 200 processed: 909668 train. 20154 val. 80957 test. 112153 no groundtruth.
# 38 of 200 processed: 934197 train. 20660 val. 83142 test. 115214 no groundtruth.
# 39 of 200 processed: 958892 train. 21196 val. 85342 test. 118230 no groundtruth.
# 40 of 200 processed: 983420 train. 21730 val. 87580 test. 121315 no groundtruth.
# 41 of 200 processed: 1008014 train. 22264 val. 89775 test. 124432 no groundtruth.
# 42 of 200 processed: 1032933 train. 22768 val. 91972 test. 127571 no groundtruth.
# 43 of 200 processed: 1057651 train. 23338 val. 94222 test. 130561 no groundtruth.
# 44 of 200 processed: 1082185 train. 23853 val. 96354 test. 133694 no groundtruth.
# 45 of 200 processed: 1106759 train. 24450 val. 98579 test. 136688 no groundtruth.
# 46 of 200 processed: 1131455 train. 24981 val. 100761 test. 139720 no groundtruth.
# 47 of 200 processed: 1156014 train. 25525 val. 102903 test. 142829 no groundtruth.
# 48 of 200 processed: 1180595 train. 26076 val. 105125 test. 145869 no groundtruth.
# 49 of 200 processed: 1205176 train. 26606 val. 107354 test. 148939 no groundtruth.
# 50 of 200 processed: 1229710 train. 27198 val. 109532 test. 151968 no groundtruth.
# 51 of 200 processed: 1254089 train. 27763 val. 111700 test. 154981 no groundtruth.
# 52 of 200 processed: 1278679 train. 28332 val. 113926 test. 157959 no groundtruth.
# 53 of 200 processed: 1303176 train. 28876 val. 116089 test. 160961 no groundtruth.
# 54 of 200 processed: 1327772 train. 29460 val. 118319 test. 163964 no groundtruth.
# 55 of 200 processed: 1352458 train. 30024 val. 120532 test. 167049 no groundtruth.
# 56 of 200 processed: 1377382 train. 30580 val. 122662 test. 170087 no groundtruth.
# 57 of 200 processed: 1401922 train. 31083 val. 124893 test. 173084 no groundtruth.
# 58 of 200 processed: 1426509 train. 31628 val. 127029 test. 176044 no groundtruth.
# 59 of 200 processed: 1451093 train. 32183 val. 129168 test. 179012 no groundtruth.
# 60 of 200 processed: 1475737 train. 32722 val. 131313 test. 182112 no groundtruth.
# 61 of 200 processed: 1500216 train. 33279 val. 133404 test. 185127 no groundtruth.
# 62 of 200 processed: 1524983 train. 33816 val. 135532 test. 188198 no groundtruth.
# 63 of 200 processed: 1549777 train. 34388 val. 137753 test. 191237 no groundtruth.
# 64 of 200 processed: 1574569 train. 34921 val. 139954 test. 194326 no groundtruth.
# 65 of 200 processed: 1599325 train. 35458 val. 142256 test. 197402 no groundtruth.
# 66 of 200 processed: 1624004 train. 36028 val. 144422 test. 200389 no groundtruth.
# 67 of 200 processed: 1648870 train. 36555 val. 146568 test. 203388 no groundtruth.
# 176 of 200 processed: 4329955 train. 95821 val. 385075 test. 534335 no groundtruth.
# 177 of 200 processed: 4354860 train. 96356 val. 387243 test. 537317 no groundtruth.
# 178 of 200 processed: 4379432 train. 96899 val. 389445 test. 540376 no groundtruth.
# 179 of 200 processed: 4403711 train. 97437 val. 391652 test. 543501 no groundtruth.
# 180 of 200 processed: 4428445 train. 97982 val. 393834 test. 546403 no groundtruth.
# 181 of 200 processed: 4452722 train. 98490 val. 395936 test. 549413 no groundtruth.
# 182 of 200 processed: 4477567 train. 98986 val. 398031 test. 552496 no groundtruth.
# 183 of 200 processed: 4502265 train. 99515 val. 400262 test. 555481 no groundtruth.
# 184 of 200 processed: 4526901 train. 100066 val. 402535 test. 558533 no groundtruth.
# 185 of 200 processed: 4551267 train. 100590 val. 404665 test. 561553 no groundtruth.
# 186 of 200 processed: 4575923 train. 101174 val. 406790 test. 564664 no groundtruth.
# 187 of 200 processed: 4600747 train. 101736 val. 409089 test. 567730 no groundtruth.
# 188 of 200 processed: 4625298 train. 102252 val. 411338 test. 570742 no groundtruth.
# 189 of 200 processed: 4650099 train. 102788 val. 413474 test. 573893 no groundtruth.
# 190 of 200 processed: 4674425 train. 103357 val. 415629 test. 576987 no groundtruth.
# 191 of 200 processed: 4699035 train. 103912 val. 417783 test. 580134 no groundtruth.
# 192 of 200 processed: 4723627 train. 104492 val. 420027 test. 583215 no groundtruth.
# 193 of 200 processed: 4748334 train. 105064 val. 422240 test. 586241 no groundtruth.
# 194 of 200 processed: 4772820 train. 105582 val. 424550 test. 589281 no groundtruth.
# 195 of 200 processed: 4797507 train. 106111 val. 426734 test. 592355 no groundtruth.
# 196 of 200 processed: 4821886 train. 106683 val. 428972 test. 595393 no groundtruth.
# 197 of 200 processed: 4846650 train. 107259 val. 431181 test. 598476 no groundtruth.
# 198 of 200 processed: 4871242 train. 107777 val. 433347 test. 601600 no groundtruth.
# 199 of 200 processed: 4895866 train. 108329 val. 435453 test. 604661 no groundtruth.
# 200 of 200 processed: 4920405 train. 108861 val. 437645 test. 607671 no groundtruth.

# %%
# !ls -lht /home/isaacj/notebooks/wikidata_embeddings/fasttext/
# Out:
# total 1.3G
# -rw-r--r-- 1 isaacj wikidev 5.4M Jan 27 22:47 wd_2020_11_02_nogt_metadata.txt
# -rw-r--r-- 1 isaacj wikidev  27M Jan 27 22:47 wd_2020_11_02_nogt.txt
# -rw-r--r-- 1 isaacj wikidev 3.9M Jan 27 22:47 wd_2020_11_02_test_metadata.txt
# -rw-r--r-- 1 isaacj wikidev  95M Jan 27 22:47 wd_2020_11_02_test.txt
# -rw-r--r-- 1 isaacj wikidev  44M Jan 27 22:47 wd_2020_11_02_train_metadata.txt
# -rw-r--r-- 1 isaacj wikidev 1.1G Jan 27 22:47 wd_2020_11_02_train.txt
# -rw-r--r-- 1 isaacj wikidev 976K Jan 27 22:47 wd_2020_11_02_val_metadata.txt
# -rw-r--r-- 1 isaacj wikidev  24M Jan 27 22:47 wd_2020_11_02_val.txt
